# %%
import numpy as np
import pandas as pd

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/car_age_price.csv')

# %%
data.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
data.isna().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Year', 'Price'], dtype='object')

# %%
x=data.drop('Price',axis=1)
y=data['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ###Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,model.predict(x_train),color='red')
plt.title('Price Prediction')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
predictions=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("Mean Square Error",mean_squared_error(y_test,predictions))
print("R Square Error",r2_score(y_test,predictions))
# Out:
# Mean Square Error 4326906256.829671
# R Square Error 0.36759313425902185

# %%
##Possible price of this car in 2022
value=model.predict([[2022]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
value
# Out:
# array([743601.61594504])

# %% [markdown]
# ###Lasso Regression

# %%
from sklearn.linear_model import Lasso
ls=Lasso()
model=ls.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,model.predict(x_train),color='red')
plt.title('Price Prediction')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
predictions=model.predict(x_test)

# %%
print("Mean Square Error",mean_squared_error(y_test,predictions))
print("R Square Error",r2_score(y_test,predictions))
# Out:
# Mean Square Error 4326859771.015669
# R Square Error 0.3675999284778446

# %%
value1=model.predict([[2022]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %%
value1
# Out:
# array([743599.37427144])

# %% [markdown]
# ###Conclusion
# Both the models give same curve and same value
# prediction of price in 2022 is 743599.37427144
