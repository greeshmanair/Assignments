# %% [markdown]
# ##Assignment on bank

# %%
class Bank_Manager:
  def _init_(self,initial=0):
    self.balance=initial
  def withdrawal(ba):
    am=float(input("Enter the amount to be withdrawn "))
    if am>ba :
        print("You are trying to withdraw amount more than your balance. Your current balance is rupees ")
        print(ba)
    elif ba==0:
        print("Your account is empty. No cash to withdraw ")
    else:
        ba=float(ba-am)
        print("Transaction success full...Your available balance is ")
        print(ba)
        return(ba)

  def balance_enquiry(bal):
      if bal==0:
        print("Your account is empty ")

      else:
        print("You have balance rupees ")
        print(bal)
        return(bal)

  def deposit(bali):
      ca=float(input("Enter the amount to be deposited "))
      if ca==0:
        print("You have not entered any amount ")
      else:
        bali=float(bali+ca)
        print("Your cash has been depositted ,Now balance is ")
        print(bali)
        return(bali)

# %%
def main():

 acc=Bank_Manager()
 while(True):
  print("Welcome to XYZ Bank. I am the Bank Manager at your service ")
  print("press 1 for Depositing amount to your account ")
  print("press 2 for withdrawal of amount ")
  print("press 3 for Balance enquiry")

  choice=int(input("Enter your option here "))
  t=(1,2,3)
  if choice not in t:
    print("Enter a valid choice ")
    r=True
  else:
     r=False



  if choice==1:
   balance=acc.deposit(balance)
  elif choice==2:
   balance=acc.withdrawal(balance)
  elif choice==3:
   balance=acc.balance_enquiry(balance)
  else:
   print("Please follow the instructions")
   break
