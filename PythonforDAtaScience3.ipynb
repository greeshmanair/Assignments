# %% [markdown]
# <a href="https://colab.research.google.com/github/greeshmanair/Assignments/blob/main/PythonforDAtaScience3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize']=5,4
sns.set_style('whitegrid')

# %%
|x=range(1,10)
y=[1,2,3,4,0.5,4,3,2,1]
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
wide=[0.5,0.5,0.5,0.9,0.9,0.9,0.5,0.5,0.5]
color=['salmon']
plt.bar(x,y,width=wide,color=color,align='center')
# Out:
# <BarContainer object of 9 artists>

# %%
cars=pd.read_csv('/content/mtcars.csv')
mpg=cars['mpg']

# %%
df=cars[['mpg','wt','cyl']]
df.plot()
# Out:
# <Axes: >

# %%
color_theme=['darkgrey','lightsalmon','powderblue']
df.plot(color=color_theme)
# Out:
# <Axes: >

# %%
z=[1,2,3,4,0.5]
plt.pie(z)
plt.show()

# %%
color_theme=['#A9A9A9','#FFA07A','blue','orange','lightgreen','#BDB768']
plt.pie(z,colors=color_theme)
plt.show()

# %%
#line styles
x1=range(1,10)
y1=[9,8,7,6,5,4,3,2,1]
plt.plot(x,y)
plt.plot(x1,y1)

# %%
plt.plot(x,y,ls='solid',lw=5)
plt.plot(x1,y1,ls='--',lw=10)

# %%
plt.plot(x,y,marker='1',mew=20)
plt.plot(x1,y1,marker='+',mew=15)

# %% [markdown]
# ##Labels and Annotations

# %%
x=range(1,10)
y=[1,2,3,4,0.5,4,3,2,1]
plt.bar(x,y)
plt.xlabel('Your xaxis')
plt.ylabel('You yaxis')
plt.show()

# %%
z=[1,2,3,4,0.5]
veh_type=['bicycle','motorbike','car','van','stroller']
plt.pie(z,labels=veh_type)
plt.show()

# %%
plt.rcParams['figure.figsize']=12,4
sns.set_style('whitegrid')
cars.columns
# Out:
# Index(['carname', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
cars.columns=['carname', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
       'am', 'gear', 'carb']
mpg=cars['mpg']
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars['carname'],rotation=60,fontsize='medium')
ax.set_title('Miles per Gallon in cars')
ax.set_xlabel('Car names')
ax.set_ylabel('miles per gallon')
ax.legend()

# %%
plt.pie(z)
plt.legend(veh_type,loc='best')
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars['carname'],rotation=60,fontsize='medium')
ax.set_title('Miles per Gallon in cars')
ax.set_xlabel('Car names')
ax.set_ylabel('miles per gallon')
ax.legend(loc='best')

# %%
#annotation
mpg.max()
# Out:
# 33.9

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars['carname'],rotation=60,fontsize='medium')
ax.set_title('Miles per Gallon in cars')
ax.set_xlabel('Car names')
ax.set_ylabel('miles per gallon')
ax.set_ylim([0,45])
ax.annotate('Toyota Corola',xy=(19,33.9),xytext=(21,35),arrowprops=dict(facecolor='black',shrink=0.05))
ax.legend()

# %% [markdown]
# ##Time Series in PYthon

# %%
df=pd.read_csv('/content/Superstore-Sales.csv',index_col='Order Date',encoding='cp1252',parse_dates=True)
df.head()
# Out:
#             Row ID  Order ID Order Priority  Order Quantity       Sales  \
# Order Date
# 2010-10-13       1         3            Low               6    261.5400
# 2012-10-01      49       293           High              49  10123.0200
# 2012-10-01      50       293           High              27    244.5700
# 2011-07-10      80       483           High              30   4965.7595
# 2010-08-28      85       515  Not Specified              19    394.2700
#
#             Discount       Ship Mode   Profit  Unit Price  Shipping Cost  \
# Order Date
# 2010-10-13      0.04     Regular Air  -213.25       38.94          35.00
# 2012-10-01      0.07  Delivery Truck   457.81      208.16          68.02
# 2012-10-01      0.01     Regular Air    46.71        8.69           2.99
# 2011-07-10      0.08     Regular Air  1198.97      195.99           3.99
# 2010-08-28      0.08     Regular Air    30.94       21.78           5.94
#
# ...

# %%
df['Order Quantity'].plot()
# Out:
# <Axes: xlabel='Order Date'>

# %%
df2=df.sample(n=100,random_state=25,axis=0)
plt.xlabel('Order Date')
plt.ylabel('Quantity')
plt.title('Super Store Sales')
df2['Order Quantity'].plot()
# Out:
# <Axes: title={'center': 'Super Store Sales'}, xlabel='Order Date', ylabel='Quantity'>

# %% [markdown]
# ##Statistical DAtagraphs

# %%
cars.index=cars.carname
mpg=cars['mpg']
mpg.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(mpg)
plt.plot()
# Out:
# []

# %%
sns.displot(mpg)

# %%
cars.plot(kind='scatter',x='hp',y='mpg',c=['darkgreen'],s=150)
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
sns.regplot(x='hp',y='mpg',data=cars,scatter=True,color='orange')
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
sns.pairplot(cars)

# %%
cars_subset=cars[['mpg','disp','hp','wt']]
sns.pairplot(cars_subset)
plt.show()

# %%
plt.rcParams['figure.figsize']=5,6
sns.set_style('whitegrid')
cars.boxplot(column='mpg',by='am')
cars.boxplot(column='wt',by='am')
# Out:
# <Axes: title={'center': 'wt'}, xlabel='am'>

# %%
sns.boxplot(x='am',y='mpg',data=cars,hue='am',palette='hls')
# Out:
# <Axes: xlabel='am', ylabel='mpg'>
