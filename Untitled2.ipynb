# %% [markdown]
# "source": [
#     "Consider the following Python dictionary `data` and Python list `labels`:\n",
#     "\n",
#     "``` python\n",
#     "data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],\n",
#     "        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],\n",
#     "        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],\n",
#     "        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}\n",
#     "\n",
#     "labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']\n",
#     "```\n",
#     "\n",
#     "**1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`."
#    ]

# %%
import numpy as np

# %%
import pandas as pd

# %%
data={'animal':['cat','cat','snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'], 'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
      'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# %%
labels=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
data
# Out:
# {'animal': ['cat',
#   'cat',
#   'snake',
#   'dog',
#   'dog',
#   'cat',
#   'snake',
#   'cat',
#   'dog',
#   'dog'],
#  'age': [2.5, 3, 0.5, nan, 5, 2, 4.5, nan, 7, 3],
#  'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#  'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# %%
df=pd.DataFrame(data,index=labels)

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
#  Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 700.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']

# %%
df[['animal','age']].iloc[[3,4,8]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
df[df.visits >3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`

# %%
df[df['age'].isna()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df1=df['animal':'cat']

# %%
df1
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
df[df['age']>=2  ]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.age.f=1.5
# Out:
# <ipython-input-75-ea94bf7281aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.age.f=1.5

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
df['visits'].sum()
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
df['age'].mean()
# Out:
# 3.375

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df['k']=['e','e','e','e','e','e','e','e','e','e']

# %%
df
# Out:
#   animal  age  visits priority  k
# a    cat  2.5       1      yes  e
# b    cat  3.0       3      yes  e
# c  snake  0.5       2       no  e
# d    dog  NaN       3      yes  e
# e    dog  5.0       2       no  e
# f    cat  1.5       3       no  e
# g  snake  4.5       1       no  e
# h    cat  NaN       1      yes  e
# i    dog  7.0       2       no  e
# j    dog  3.0       1       no  e

# %%
del df['k']

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
df['animal'].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df.sort_values(by=['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`."

# %%
df['priority'].convert_dtypes(bool)
# Out:
# a    yes
# b    yes
# c     no
# d    yes
# e     no
# f     no
# g     no
# h    yes
# i     no
# j     no
# Name: priority, dtype: string

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df.animal.snake='python'

# %%
df['animal']
# Out:
# a      cat
# b      cat
# c    snake
# d      dog
# e      dog
# f      cat
# g    snake
# h      cat
# i      dog
# j      dog
# Name: animal, dtype: object

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
data=pd.read_excel('/content/ny-flights.xlsx')

# %%
data.head()
# Out:
#      fl_date unique_carrier  airline_id tail_num  fl_num origin dest  \
# 0 2014-01-01             AA       19805   N338AA       1    JFK  LAX
# 1 2014-01-01             AA       19805   N335AA       3    JFK  LAX
# 2 2014-01-01             AA       19805   N327AA      21    JFK  LAX
# 3 2014-01-01             AA       19805   N3EHAA      29    LGA  PBI
# 4 2014-01-01             AA       19805   N319AA     117    JFK  LAX
#
#    dep_time  dep_delay  arr_time  arr_delay  cancelled                 arr  \
# 0     914.0       14.0    1238.0       13.0          0 2014-01-01 12:38:00
# 1    1157.0       -3.0    1523.0       13.0          0 2014-01-01 15:23:00
# 2    1902.0        2.0    2224.0        9.0          0 2014-01-01 22:24:00
# 3     722.0       -8.0    1014.0      -26.0          0 2014-01-01 10:14:00
# 4    1347.0        2.0    1706.0        1.0          0 2014-01-01 17:06:00
#
#                   dep
# 0 2014-01-01 09:14:00
# 1 2014-01-01 11:57:00
# 2 2014-01-01 19:02:00
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
data['fl_num'].value_counts().max()
# Out:
# 89

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=data['dep_delay']
y=data['arr_delay']
plt.plot(x,y)
plt.show()
