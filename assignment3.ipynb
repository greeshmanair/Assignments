# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_excel('/content/iris.xls')

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.tail(10)
# Out:
#       SL   SW   PL   PW  Classification
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %%
#Mean of SL
data['SL'].mean()
# Out:
# 5.843333333333334

# %%
#Mean of SW
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
#Mean of PL
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
#Mean of PW
data['PW'].mean()
# Out:
# 1.1986666666666668

# %%
#Null values in dataset
data['PL'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: PL, Length: 150, dtype: bool

# %% [markdown]
# ###There are no null values in column PL

# %%
data['PW'].notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: PW, Length: 150, dtype: bool

# %% [markdown]
# ###No null values in PW

# %%
data['SL'].notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: SL, Length: 150, dtype: bool

# %%
data['SW'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: SW, Length: 150, dtype: bool

# %% [markdown]
# ###Both SL and SW also does not have any null values

# %%
#Data Visualisation
data['PL'].nunique()
# Out:
# 43

# %%
data['PW'].nunique()
# Out:
# 22

# %%
data['SL'].nunique()
# Out:
# 35

# %%
data['SW'].nunique()
# Out:
# 23

# %%
sns.barplot(x=data['Classification'],y=data['PL'],palette='Dark2')
plt.show()
# Out:
# <ipython-input-40-3cd41f6d12d3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Classification'],y=data['PL'],palette='Dark2')

# %%
sns.barplot(x=data['Classification'],y=data['PW'],palette='Dark2')
plt.show()
# Out:
# <ipython-input-42-4bc3e0c1ecbc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Classification'],y=data['PW'],palette='Dark2')

# %%
sns.barplot(x=data['Classification'],y=data['SL'],palette='Dark2')
plt.show()
# Out:
# <ipython-input-44-d0274f5ef331>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Classification'],y=data['SL'],palette='Dark2')

# %%
sns.barplot(x=data['Classification'],y=data['SW'],palette='Dark2')
plt.show()
# Out:
# <ipython-input-45-50aedbe21623>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Classification'],y=data['SW'],palette='Dark2')

# %% [markdown]
# #Conclusion
# The data set defines the features of three types of flowers:
# ###Iris-virginca
#     it has sepal width around 3cm
#     it has sepal lenght around 6cm
#     it has petal width around 2cm
#     it has petal length around 6cm
# ###Iris-versicolor
#     it has sepal width around 2.5cm
#     it has sepal lenght around 5.5cm
#     it has petal width around 1.25cm
#     it has petal length around 5cm
# ###Iris-setosa
#     it has sepal width around 3.5cm
#     it has sepal lenght around 5cm
#     it has petal width around 0.25cm
#     it has petal length around 1.5cm

# %%
data['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
d1=data.groupby('Classification')

# %%
d1.head()
# Out:
#       SL   SW   PL   PW   Classification
# 0    5.1  3.5  1.4  0.2      Iris-setosa
# 1    4.9  3.0  1.4  0.2      Iris-setosa
# 2    4.7  3.2  1.3  0.2      Iris-setosa
# 3    4.6  3.1  1.5  0.2      Iris-setosa
# 4    5.0  3.6  1.4  0.2      Iris-setosa
# 50   7.0  3.2  4.7  1.4  Iris-versicolor
# 51   6.4  3.2  4.5  1.5  Iris-versicolor
# 52   6.9  3.1  4.9  1.5  Iris-versicolor
# 53   5.5  2.3  4.0  1.3  Iris-versicolor
# 54   6.5  2.8  4.6  1.5  Iris-versicolor
# 100  6.3  3.3  6.0  2.5   Iris-virginica
# 101  5.8  2.7  5.1  1.9   Iris-virginica
# 102  7.1  3.0  5.9  2.1   Iris-virginica
# 103  6.3  2.9  5.6  1.8   Iris-virginica
# 104  6.5  3.0  5.8  2.2   Iris-virginica
